# %%
import numpy as np
import random
#import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
dataset = np.array([[5.7, 55], [5.9, 81], [5.1, 58], [6.1, 84], [5.6, 66], [5.2, 53]])
print(dataset.shape)
# Out:
# (6, 2)

# %%
m = dataset.shape[0]
n = dataset.shape[1]

k = 4

# %%
kMeans = KMeans(k)
kMeans.fit(dataset)
identified_clusters = kMeans.fit_predict(dataset)
print(identified_clusters)
# Out:
# [2 1 0 1 3 2]

# %%
from sklearn.datasets._samples_generator import make_blobs
X, y = make_blobs(n_samples=20, centers=20)
from kmeans import k_means_clustering
k_means_clustering(X, k)
# Out:
# [[ 4.38896121 -8.58304263]
#  [ 4.02564819 10.0082429 ]
#  [ 1.19745773  4.0926886 ]
#  [-0.45654109  6.4023977 ]]
# CLASSES {3: [array([-9.7016199 ,  9.32499584]), array([-6.75775599,  5.56712812]), array([-7.25010301,  8.69871386]), array([0.07368782, 8.73847853]), array([-6.05758511,  5.65004401]), array([-0.45654109,  6.4023977 ])], 0: [array([ 4.38896121, -8.58304263]), array([-3.68156041, -7.52058292]), array([ 5.51440072, -4.94424887]), array([ 2.78265041, -2.93817081]), array([-2.10293356, -5.46587339])], 2: [array([5.5815617 , 1.27017838]), array([1.19745773, 4.0926886 ]), array([-0.89236507, -0.77186342]), array([-3.29442394, -1.28620707]), array([-1.29288009,  3.52258825]), array([3.19566277, 3.4199938 ])], 1: [array([8.12508662, 9.00327163]), array([6.5483725 , 5.65856489]), array([ 4.02564819, 10.0082429 ])]}
# ...

# %%
from kmedoids import k_medoids_clustering
k_medoids_clustering(X, k)
# Out:
# [[-3.29442394 -1.28620707]
#  [ 5.5815617   1.27017838]
#  [-1.29288009  3.52258825]
#  [ 5.51440072 -4.94424887]]
# CLASSES {2: [array([-9.7016199 ,  9.32499584]), array([-6.75775599,  5.56712812]), array([1.19745773, 4.0926886 ]), array([-7.25010301,  8.69871386]), array([0.07368782, 8.73847853]), array([ 4.02564819, 10.0082429 ]), array([-1.29288009,  3.52258825]), array([-6.05758511,  5.65004401]), array([-0.45654109,  6.4023977 ])], 3: [array([ 4.38896121, -8.58304263]), array([ 5.51440072, -4.94424887]), array([ 2.78265041, -2.93817081])], 0: [array([-3.68156041, -7.52058292]), array([-0.89236507, -0.77186342]), array([-2.10293356, -5.46587339]), array([-3.29442394, -1.28620707])], 1: [array([5.5815617 , 1.27017838]), array([8.12508662, 9.00327163]), array([6.5483725 , 5.65856489]), array([3.19566277, 3.4199938 ])]}
# CLUSTERS [2, 3, 0, 2, 1, 1, 2, 3, 2, 1, 3, 2, 2, 0, 0, 0, 2, 2, 1, 2]
# ...
